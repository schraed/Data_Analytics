# %%
from cmdstanpy import CmdStanModel
import pandas as pd
import arviz as az 
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
#Excercise 1  

gen_quant = CmdStanModel(stan_file='code_1.stan')

# %%
F = len('Michal')
L = len('Solek')

# %%
samples = gen_quant.sample(data = {'M':F},
                           fixed_param=True,
                           iter_sampling=1000,
                           iter_warmup=0,
                           chains = 1)
# Out:
# 23:05:45 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# 23:05:45 - cmdstanpy - INFO - CmdStan done processing.

# %%
df = samples.draws_pd()
df
# Out:
#      lp__  accept_stat__    lambda  y_sim[1]  y_sim[2]  y_sim[3]  y_sim[4]  \
# 0     0.0            0.0   32.5826      33.0      38.0      27.0      22.0
# 1     0.0            0.0  134.0180     125.0     148.0     125.0     132.0
# 2     0.0            0.0  133.0280     125.0     140.0     128.0     111.0
# 3     0.0            0.0   52.8153      45.0      44.0      67.0      50.0
# 4     0.0            0.0   67.9211      73.0      65.0      67.0      66.0
# ..    ...            ...       ...       ...       ...       ...       ...
# 995   0.0            0.0  170.1350     148.0     180.0     177.0     183.0
# 996   0.0            0.0  163.9660     173.0     168.0     163.0     192.0
# 997   0.0            0.0  107.3670     111.0      98.0      87.0     101.0
# 998   0.0            0.0   48.9374      51.0      58.0      55.0      43.0
# 999   0.0            0.0   42.8299      53.0      43.0      49.0      39.0
#
#      y_sim[5]  y_sim[6]
# 0        31.0      34.0
# ...

# %%
Lambda = df['lambda']
Lambda.plot.hist(bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2 = df.drop(df.columns[0:3], axis=1)
df2.plot.hist(subplots=True, bins=30)

# %%
#Excercise2
bern1 = CmdStanModel(stan_file='code_2.stan')
samp_bern1 = bern1.sample(data={'N':2, 'y':[0, 1]})

#when 'y' is set as [0:2] there is a lot of errors
# Out:
# 00:18:19 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 00:18:19 - cmdstanpy - INFO - CmdStan done processing.

# %%
bern2 = CmdStanModel(stan_file='code_3.stan')
samp_bern2 = bern2.sample(data={'N':2, 'y':[0,1]})

#when 'y' is set as [0:2] there is a lot of errors
# Out:
# 00:23:03 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 00:23:03 - cmdstanpy - INFO - CmdStan done processing.

# %%
#Excercise3

model_gm1 = CmdStanModel(stan_file='code_4.stan')
#out_gamma1 = model_gm1.sample(output_dir='samples', iter_sampling=6000, iter_warmup=1000, seed=4838282)
#out_gamma1.diagnose()

#this two lines of code are commented beacuse it generates a lot of warnings

# %%
N = 500
xs = np.linspace(0,8,N)
pdfs = stats.gamma.pdf(xs, 1.25, scale = 1/1.25)

plt.plot(xs, pdfs, linewidth=2)

## add histogram of theta samples with 160 bins

plt.gca().set_xlabel("theta")
plt.gca().set_ylabel("Probability Density Function")
plt.show()

# %%
model_gm2 = CmdStanModel(stan_file='code_5.stan')
out_gamma2 = model_gm2.sample(output_dir='samples', iter_sampling=6000, iter_warmup=1000, seed=4838282)
out_gamma2.diagnose()
# Out:
# 00:45:31 - cmdstanpy - INFO - compiling stan file C:\Users\micha\Data_Analytics\Lab2\code_5.stan to exe file C:\Users\micha\Data_Analytics\Lab2\code_5.exe
# 00:45:41 - cmdstanpy - INFO - compiled model executable: C:\Users\micha\Data_Analytics\Lab2\code_5.exe
# 00:45:41 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 00:45:41 - cmdstanpy - INFO - CmdStan done processing.
# 00:45:42 - cmdstanpy - WARNING - Some chains may have failed to converge.
# 	Chain 3 had 1 divergent transitions (0.0%)
# 	Use function "diagnose()" to see further information.
# ...

# %%
N=500
xs = np.linspace(0,8,N)
pdfs = stats.gamma.pdf(xs, 1.25, scale = 1 / 1.25) 

plt.plot(xs, pdfs, linewidth=2)

## add histogram of theta samples from the second model with 160 bins

plt.gca().set_xlabel("theta")
plt.gca().set_ylabel("Probability Density Function")
plt.show()

# %%
#Excercise4

model_tune = CmdStanModel(stan_file='code_6.stan')

#F = # number of letters in the first name
#L = # number of letters in the last name
y0 = 1 # initial guess for the equation solving

data={'y_guess':[y0],
        'theta':[(F+L)/2]}
tunes = model_tune.sample(data=data, fixed_param=True, iter_sampling=1, iter_warmup=0, chains = 1)
tunes.draws_pd()
# Out:
# 00:59:47 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# 00:59:47 - cmdstanpy - INFO - CmdStan done processing.
#    lp__  accept_stat__    sigma
# 0   0.0            0.0  2.13523

# %%
#Excercise5
model_samp_st = CmdStanModel(stan_file='code_7.stan')
model_log_target = CmdStanModel(stan_file='code_8.stan')
model_log_target_ind = CmdStanModel(stan_file='code_9.stan')
data = {'N': F}
seed = 15052000#integer, your date of birth in the DDMMYYYY format without leading zero (or if you are GPRD weary, use any other date you wish)
result_1 = model_samp_st.sample(data=data,seed=seed)
result_2 = model_log_target.sample(data=data,seed=seed)
result_3 = model_log_target_ind.sample(data=data,seed=seed)
# Out:
# 01:10:38 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 01:10:38 - cmdstanpy - INFO - CmdStan done processing.
# 01:10:39 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 01:10:39 - cmdstanpy - INFO - CmdStan done processing.
# 01:10:39 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 01:10:39 - cmdstanpy - INFO - CmdStan done processing.

# %%
az.plot_density([result_1,result_2,result_3])
plt.show()

# %%
#Excercise6
model_gq = CmdStanModel(stan_file='code_10.stan')
# fill in with chosen result from previous excercise
mean_of_y = model_gq.generate_quantities(data=data,
                                        mcmc_sample = result_3)
# investigate the output and plot histogram of mean_y variable
#df = mean_of_y.generated_quantities_pd 

#df generates Value and Atribute errors
# Out:
# 01:18:27 - cmdstanpy - WARNING - Argument name `mcmc_sample` is deprecated, please rename to `previous_fit`.
# 01:18:27 - cmdstanpy - INFO - Chain [1] start processing
# 01:18:27 - cmdstanpy - INFO - Chain [2] start processing
# 01:18:27 - cmdstanpy - INFO - Chain [3] start processing
# 01:18:27 - cmdstanpy - INFO - Chain [4] start processing
# 01:18:27 - cmdstanpy - INFO - Chain [1] done processing
# 01:18:27 - cmdstanpy - INFO - Chain [2] done processing
# 01:18:27 - cmdstanpy - INFO - Chain [4] done processing
# 01:18:27 - cmdstanpy - INFO - Chain [3] done processing

# %%
plt.hist(mean_of_y.mean_y, bins = 20)
# Out:
# (array([  4.,   9.,  39.,  58., 166., 245., 342., 414., 497., 563., 506.,
#         416., 323., 181., 128.,  55.,  26.,  15.,  10.,   3.]),
#  array([-3.26977, -2.9222 , -2.57463, -2.22706, -1.87949, -1.53192,
#         -1.18435, -0.83678, -0.48921, -0.14164,  0.20593,  0.5535 ,
#          0.90107,  1.24864,  1.59621,  1.94378,  2.29135,  2.63892,
#          2.98649,  3.33406,  3.68163]),
#  <BarContainer object of 20 artists>)
